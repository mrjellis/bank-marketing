# %%
cd
# Out:
# C:\Users\John's PC

# %%
os.listdir()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-67fdccf289bf> in <module>
# ----> 1 os.listdir()
#
# NameError: name 'os' is not defined

# %%
import os

# %%
os.getcwd()
# Out:
# "C:\\Users\\John's PC"

# %%
os.chdir(r"C:\Users\John's PC\Documents\Python Stuff\Projects\Data Science\Categorical\Bank Marketing")

# %%
os.getcwd()
# Out:
# "C:\\Users\\John's PC\\Documents\\Python Stuff\\Projects\\Data Science\\Categorical\\Bank Marketing"

# %%
# %run connect.py
# Out:
# Database connected succesful

# %%
# Out:
#             id  age            job   marital  education default  balance  \
# 0          1.0   58     management   married   tertiary      no   2143.0
# 1          2.0   44     technician    single  secondary      no     29.0
# 2          3.0   33   entrepreneur   married  secondary      no      2.0
# 3          4.0   47    blue-collar   married    unknown      no   1506.0
# 4          5.0   33        unknown    single    unknown      no      1.0
# 5          6.0   35     management   married   tertiary      no    231.0
# 6          7.0   28     management    single   tertiary      no    447.0
# 7          8.0   42   entrepreneur  divorced   tertiary     yes      2.0
# 8          9.0   58        retired   married    primary      no    121.0
# 9         10.0   43     technician    single  secondary      no    593.0
# 10        11.0   41         admin.  divorced  secondary      no    270.0
# 11        12.0   29         admin.    single  secondary      no    390.0
# ...
